# %%
from google.colab import drive

drive.mount('/content/gdrive/')

from google.colab import drive
drive.mount('/content/gdrive/')
import sys
sys.path.append('/content/gdrive/My Drive/Sleep_Data_Imputation_Handling')
import os
os.chdir('/content/gdrive/My Drive/Sleep_Data_Imputation_Handling')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
! pip install surprise
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
import numpy as np
# from tqdm import tqdm
from tqdm.notebook import tqdm_notebook as tqdm
import torch.nn.functional as F
import torch.nn as nn
import random

import math

import pandas as pd

import argparse

# %%
from models.sleep_model import simple_model
from models.nmf_embed import pad_NMF, sleep_NMF, find_opt_num_feat
from models.early_stopping import EarlyStopping

from models.find_threshold import find_optimal_threshold

from data.loader import Dataset

from individual_model import individual_model_handle
from global_model import global_model_handle

# %%
global_model_handle('synthetic_data.csv', 'evaluate', 'tune')
# Out:
# Validation loss decreased (inf --> 0.309540).  Saving model ...
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping
# ------------------------------------
# Type  1
# Total_sleep:  40
# AccSleep:  1.0
# Total_wake:  1630
# AccWake:  0.5883435582822086
# ------------------------------------
# Type  2
# Total_sleep:  0
# Total_wake:  892
# AccWake:  0.7118834080717489
# ------------------------------------
# Type  3
# Total_sleep:  0
# Total_wake:  853
# AccWake:  0.5943728018757327
#         prob  ground  type  pred      acti       NMF  denote
# 0        1.0     1.0     0     1  0.703364  0.617930     1.0
# ...

# %%
individual_model_handle('Ehwa_data/SWSI039_timeseries.csv', 'evaluate', param_choice='default')
# Out:
# Validation loss decreased (inf --> 0.336384).  Saving model ...
# Validation loss decreased (0.336384 --> 0.322886).  Saving model ...
# Validation loss decreased (0.322886 --> 0.322705).  Saving model ...
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping
# ------------------------------------
# Type  1
# Total_sleep:  334
# AccSleep:  1.0
# Total_wake:  1779
# AccWake:  0.7880831928049467
# ------------------------------------
# Type  2
# Total_sleep:  105
# AccSleep:  0.8666666666666667
# Total_wake:  553
# AccWake:  0.8535262206148282
# ------------------------------------
# Type  3
# Total_sleep:  191
# AccSleep:  0.9267015706806283
# ...
